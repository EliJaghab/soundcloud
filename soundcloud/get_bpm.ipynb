# %%
import requests
import base64
import datetime

# %%
client_id = "d22e1351aa4a4ddfb7c0550137efdd7a"
client_secret = "7f23c73eb6cb447ea7dbb1840b43d778"

# %%
token_url = "https://accounts.spotify.com/api/token"

# %%
client_creds = f"{client_id}:{client_secret}"
client_creds_b64 = base64.b64encode(client_creds.encode())

# %%
method = "POST"
token_data = {
    "grant_type": "client_credentials"
}

token_headers = {
    "Authorization": f"Basic {client_creds_b64.decode()}",
    "Content-Type": "application/x-www-form-urlencoded"
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/eli/github/soundcloud/get_bpm.ipynb Cell 5' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/eli/github/soundcloud/get_bpm.ipynb#ch0000004?line=0'>1</a> method = "POST"
#       <a href='vscode-notebook-cell:/Users/eli/github/soundcloud/get_bpm.ipynb#ch0000004?line=1'>2</a> token_data = {
#       <a href='vscode-notebook-cell:/Users/eli/github/soundcloud/get_bpm.ipynb#ch0000004?line=2'>3</a>     "grant_type": "client_credentials"
#       <a href='vscode-notebook-cell:/Users/eli/github/soundcloud/get_bpm.ipynb#ch0000004?line=3'>4</a> }
#       <a href='vscode-notebook-cell:/Users/eli/github/soundcloud/get_bpm.ipynb#ch0000004?line=5'>6</a> token_headers = {
# ...

# %%
response = requests.post(token_url, data = token_data, headers = token_headers)
valid_request = response.status_code in range(200, 299)

# %%
if valid_request:
    token_response_data = response.json()
    now = datetime.datetime.now()
    access_token = token_response_data['access_token']
    expires_in = token_response_data['expires_in']
    expires = now + datetime.timedelta(seconds = expires_in)
    did_expire = expires < now

# %%
print(access_token)
# Out:
# BQB6knmIRceo03cW46TYomx0cUyhL_ioDwSIasFeMzkTMmEPrjZECMogC3833JmW4n9TlnRDRqFNlN7fpD-7X-AXyS4fdRxG0MT2HyoMjM-xuTMpHB4

# %%
header = {
    "Authorization": f"Bearer{access_token}"
}

endpoint = "https://api.spotify.com/v1/search"

# %%
AUTH_URL = 'https://accounts.spotify.com/api/token'

# POST
auth_response = requests.post(AUTH_URL, {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret,
})

# convert the response to JSON
auth_response_data = auth_response.json()

# save the access token
access_token = auth_response_data['access_token']

# %%
headers = {
    'Authorization': 'Bearer {token}'.format(token=access_token)
}

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)

# %%
r = r.json()
r
# Out:
# {'danceability': 0.54,
#  'energy': 0.59,
#  'key': 0,
#  'loudness': -4.359,
#  'mode': 1,
#  'speechiness': 0.0528,
#  'acousticness': 0.446,
#  'instrumentalness': 0,
#  'liveness': 0.14,
#  'valence': 0.267,
#  'tempo': 119.878,
#  'type': 'audio_features',
#  'id': '6y0igZArWVi6Iz0rj35c1Y',
#  'uri': 'spotify:track:6y0igZArWVi6Iz0rj35c1Y',
#  'track_href': 'https://api.spotify.com/v1/tracks/6y0igZArWVi6Iz0rj35c1Y',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6y0igZArWVi6Iz0rj35c1Y',
#  'duration_ms': 234910,
#  'time_signature': 4}

# %%
des_url = "https://api.spotify.com/v1/search?q=track:"' + despacito + '"%20artist:"' + bieber + '"&type=track"

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

scope = "user-library-read"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,client_secret=client_secret,redirect_uri="http://localhost:8080",scope=scope))

# %%
track_id = sp.search()

# %%
results = spotify.search(q='artist:' + name, type='artist')

# %%
from pprint import pprint

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret = client_secret))

artist= 'Lil Yachty'
track= 'Yacht Club'

track_id = sp.search(q='artist:' + artist + ' track:' + track, type='track')
yacht_club = track_id['tracks']['items'][0]['external_urls']['spotify'][31:]

# %%
class SpotifyAPI():
    def __init__(self):
        sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=client_id, client_secret = client_secret))

# %%
pprint(sp.audio_features(yacht_club))
# Out:
# [{'acousticness': 0.317,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5R2rsbwCDXORX2tLfprRmM',
#   'danceability': 0.721,
#   'duration_ms': 166343,
#   'energy': 0.508,
#   'id': '5R2rsbwCDXORX2tLfprRmM',
#   'instrumentalness': 0,
#   'key': 7,
#   'liveness': 0.153,
#   'loudness': -7.496,
#   'mode': 1,
#   'speechiness': 0.394,
#   'tempo': 159.911,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/5R2rsbwCDXORX2tLfprRmM',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5R2rsbwCDXORX2tLfprRmM',
#   'valence': 0.457}]

# %%
# base URL of all Spotify API endpoints
BASE_URL = 'https://api.spotify.com/v1/'

# Track ID from the URI
track_id = '6y0igZArWVi6Iz0rj35c1Y'

# actual GET request with proper header
r = requests.get(BASE_URL + 'audio-features/' + track_id, headers=headers)

# %%
from pprint import pprint

# %%
import json

with open('liked_songs5_19_22.json') as f:
  tracks = json.load(f)

for track in tracks:
    print(track['title'].replace(" ", "%20"), track['artist'])

    break
# Out:
# Ultrabeat%20-%20Pretty%20Green%20Eyes%20(James%20Mawdesley%20Remix) James Mawdesley

# %%
count = 0
for track in tracks:
    count += 1
    track_title = track['title'].replace(" ", "%20")
    track_artist = track['artist'].replace(" ", "%20")
    track_url = f"https://api.spotify.com/v1/search?q=track:{track_title}artist:{track_artist}&type=track"
    response = requests.get(track_url, headers = headers)
    if count == 5:
        print(track_title)
        print(track_artist)
        print(response.text)
        break
# Out:
# Martin%20Garrix%20&%20Zedd%20-%20Follow
# Martin%20Garrix
# {
#   "tracks" : {
#     "href" : "https://api.spotify.com/v1/search?query=track%3AMartin+Garrix+&type=track&offset=0&limit=20",
#     "items" : [ {
#       "album" : {
#         "album_type" : "single",
#         "artists" : [ {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/60d24wfXkVzDSfLS6hyCjZ"
#           },
#           "href" : "https://api.spotify.com/v1/artists/60d24wfXkVzDSfLS6hyCjZ",
#           "id" : "60d24wfXkVzDSfLS6hyCjZ",
#           "name" : "Martin Garrix",
#           "type" : "artist",
#           "uri" : "spotify:artist:60d24wfXkVzDSfLS6hyCjZ"
#         }, {
#           "external_urls" : {
#             "spotify" : "https://open.spotify.com/artist/2auikkNYqigWStoHWK1Grq"
#           },
#           "href" : "https://api.spotify.com/v1/artists/2auikkNYqigWStoHWK1Grq",
#           "id" : "2auikkNYqigWStoHWK1Grq",
#           "name" : "John Martin",
# ...

# %%
response = requests.get('https://api.spotify.com/v1/search?q=track:I%20need%20a hero%20artist:the%20artist&type=track', headers = headers)
pprint(response.text)
# Out:
# ('{\n'
#  '  "tracks" : {\n'
#  '    "href" : '
#  '"https://api.spotify.com/v1/search?query=track%3AI+need+a+hero+artist%3Athe+artist&type=track&offset=0&limit=20",\n'
#  '    "items" : [ {\n'
#  '      "album" : {\n'
#  '        "album_type" : "album",\n'
#  '        "artists" : [ {\n'
#  '          "external_urls" : {\n'
#  '            "spotify" : '
#  '"https://open.spotify.com/artist/21iJ0sfITnAGHIFS3UQmk3"\n'
#  '          },\n'
#  '          "href" : '
#  '"https://api.spotify.com/v1/artists/21iJ0sfITnAGHIFS3UQmk3",\n'
#  '          "id" : "21iJ0sfITnAGHIFS3UQmk3",\n'
#  '          "name" : "The Pop Heroes",\n'
#  '          "type" : "artist",\n'
#  '          "uri" : "spotify:artist:21iJ0sfITnAGHIFS3UQmk3"\n'
#  '        } ],\n'
#  '        "available_markets" : [ "AD", "AE", "AG", "AL", "AM", "AO", "AR", '
#  '"AT", "AU", "AZ", "BA", "BB", "BD", "BE", "BF", "BG", "BH", "BI", "BJ", '
#  '"BN", "BO", "BR", "BS", "BT", "BW", "BY", "BZ", "CA", "CD", "CG", "CH", '
# ...
